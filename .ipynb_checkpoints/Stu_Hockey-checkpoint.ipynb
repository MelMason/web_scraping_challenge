# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Coyle, Bruins find inspiration in 3-year-old who had brain tumor
# Quinn Waters to drop puck against Sharks as part of Hockey Fights Cancer month
# 2019-10-28
# -----------------
# Marchand leads 3 Stars of the Week
# Bruins forward, Predators defenseman Josi, Flyers goalie Elliott earn honors
# 2019-10-28
# -----------------
# Tarasenko to have surgery, re-evaluated in five months by Blues
# Forward injured in win against Kings
# 2019-10-28
# -----------------
# Facts and Figures: Ekblad, Boyle, Acciari power Panthers
# Score three goals in 2:36 of second, fastest to start period in Florida history
# 2019-10-28
# -----------------
# Fantasy hockey top 10 waiver wire pickups
# Compher, van Riemsdyk producing in top-six roles; Koskinen, Elliott timeshare goalies to consider
# 2019-10-28
# -----------------
# Projected lineups, starting goalies for today
# Latest line combinations, defense pairs, injury news from NHL.com writers
# 2019-10-28
# -----------------
# Red Wings' patience tested during eight-game losing streak
# Encouraging signs not enough in OT loss to Blues
# 2019-10-27
# -----------------
# McDavid against Crosby, Getzlaf's 1,000th game highlight week in NHL
# Stamkos eyeing 400th goal, Sabres-Coyotes matchup among can't-miss events
# 2019-10-28
# -----------------
# Color of Hockey: Abercrombie takes next step toward NHL coaching dream
# Hockey Is For Everyone alumnus joins NCAA Division III Stevenson as assistant
# 2019-10-28
# -----------------
# Fantasy hockey line top 25 rankings for 2019-20
# Two Flyers units join list; rookie Hughes settling in on Devils' first trio; Stars drop out
# 2019-10-27
# -----------------
# Rookie watch: Samsonov, Demko among top first-year goalies
# Young players learning, growing while performing in backup roles for Capitals, Canucks
# 2019-10-28
# -----------------
# Blackhawks roll out purple carpet for Hockey Fights Cancer night
# Olczyk emcees as team honors survivors, families of those lost
# 2019-10-27
# -----------------
# Krueger has Sabres playing connected during fast start
# Coach helped build players' confidence, believing early success is sustainable
# 2019-10-27
# -----------------
# Syndergaard rides Zamboni, shoots T-shirt cannon at Islanders game
# Mets pitcher makes appearance at Nassau Coliseum on Sunday
# 2019-10-27
# -----------------
# NHL DFS picks, projections, strategy
# Hughes has power-play point streak on Canucks' first unit; more daily fantasy targets
# 2019-10-28
# -----------------
# Jets hoping to build on win against Flames in Heritage Classic
# Comeback can provide spark to end scoring woes
# 2019-10-27
# -----------------
# Martin, Kuhnhackl out 4-6 weeks for Islanders
# Each forward has lower-body injury
# 2019-10-27
# -----------------
# Parros hustles back from Heritage Classic for charity game in New York
# Joins other former NHL players, celebrities for Face Off to Fight Cancer
# 2019-10-27
# -----------------
# Lowry to have hearing for actions in Jets game against Flames
# Forward facing discipline for boarding Kylington
# 2019-10-27
# -----------------
# 2019-20 NHL Trade Tracker
# Official deals since June 14
# 2019-10-26
# -----------------
# Gaudreau, Flames' top line show positive signs in Heritage Classic
# Forward combines with Lindholm, Tkachuk to create chances, score only goal against Jets
# 2019-10-27
# -----------------
# Gudbranson traded to Ducks by Penguins
# Pittsburgh receives forward Martinsen, seventh-round pick in 2021 NHL Draft
# 2019-10-25
# -----------------
# NHL fantasy team power rankings for 2019-20
# Kane's power-play impact has Sharks trending up; Bailey emerges as streaming option from Islanders
# 2019-10-25
# -----------------
# Heritage Classic Diary: Bryan Little
# Jets center describes 'awesome feeling' scoring in overtime outdoors against Flames
# 2019-10-27
# -----------------
# Fantasy hockey top 200 rankings for 2019-20
# Eichel joins first 25; Oshie gives Capitals six among 100 best; Burakovsky added to list after Rantanen injury
# 2019-10-25
# -----------------
# Oct. 28: Orr scores final NHL goal
# Plus: 100th shutout for Sawchuk; Crosby gets first hat trick
# 2019-10-28

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5db4e75f37f2594786350d9e'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350d9f'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da0'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da1'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da2'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da3'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da4'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da5'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da6'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da7'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da8'), 'title': None}
# {'_id': ObjectId('5db4e75f37f2594786350da9'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350daa'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350dab'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350dac'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350dad'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350dae'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350daf'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350db0'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350db1'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350db2'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350db3'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350db4'), 'title': None}
# {'_id': ObjectId('5db4e7a837f2594786350db5'), 'title': None}
# {'_id': ObjectId('5db4e7e937f2594786350db6'), 'title': '\n\n\n                                                                                                LIVE: Blues at Bruins\n                                                                                            \n\n                                                                                                St. Louis visits Boston in Stanley Cup Final rematch\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350db7'), 'title': '\n\n\n                                                                                                LIVE: Predators at Lightning\n                                                                                            \n\n                                                                                                Nashville eyes point in 12th consecutive game against Tampa Bay\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350db8'), 'title': "\n\n\n                                                                                                Voracek's sneaky goal\n                                                                                            \n\n                                                                                                Jakub Voracek fires a sharp-angle shot that gets through Joonas Korpisalo\n                                                                                            \n\n\n\n\n\n\n"}
# {'_id': ObjectId('5db4e7e937f2594786350db9'), 'title': '\n\n\n                                                                                                Hawerchuk on minds during NHL Legacy Luncheon\n                                                                                            \n\n                                                                                                Former Jets captain, member of Hockey Hall of Fame, has stomach cancer\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dba'), 'title': '\n\n\n                                                                                                NHL DFS picks, projections, strategy\n                                                                                            \n\n                                                                                                Islanders goalies stingy during six-game winning streak; more daily fantasy targets\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dbb'), 'title': '\n\n\n                                                                                                Svechnikov wires home PPG\n                                                                                            \n\n                                                                                                Andrei Svechnikov stickhandles to the circle and rifles a wrister that beats Corey Crawford short side for his first NHL power-play goal and a 1-0 lead\n                                                                                            \n\n\n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dbc'), 'title': '\n\n\n                                                                                                Oct. 26: Gretzky becomes first NHL player with 2,000 points\n                                                                                            \n\n                                                                                                Plus: Lemieux scores 500th goal; Sabres win 10th straight game from start of season\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dbd'), 'title': '\n\n\n                                                                                                NHL DFS picks, projections, strategy\n                                                                                            \n\n                                                                                                Islanders goalies stingy during six-game winning streak; more daily fantasy targets\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dbe'), 'title': '\n\n\n                                                                                                Svechnikov wires home PPG\n                                                                                            \n\n                                                                                                Andrei Svechnikov stickhandles to the circle and rifles a wrister that beats Corey Crawford short side for his first NHL power-play goal and a 1-0 lead\n                                                                                            \n\n\n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dbf'), 'title': "\n\n\n                                                                                                Saskamoose meets Bettman\n                                                                                            \n\n                                                                                                NHL's first indigenous player expressed honor of having Heritage Classic in Saskatchewan\n                                                                                            \n\n\n\n\n"}
# {'_id': ObjectId('5db4e7e937f2594786350dc0'), 'title': '\n\n\n\n\n\n\n\n\n\n'}
# {'_id': ObjectId('5db4e7e937f2594786350dc1'), 'title': '\n\n\n                                                                                                2019 Class Induction: Nov. 15-18\n                                                                                            \n\n                                                                                                Celebrate Carbonneau, Nedomansky, Rutherford, Wickenheiser, York & Zubov November 15-18 in Toronto\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc2'), 'title': '\n\n\n                                                                                                LIVE: Blues at Bruins\n                                                                                            \n\n                                                                                                St. Louis visits Boston in Stanley Cup Final rematch\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc3'), 'title': '\n\n\n                                                                                                LIVE: Predators at Lightning\n                                                                                            \n\n                                                                                                Nashville eyes point in 12th consecutive game against Tampa Bay\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc4'), 'title': "\n\n\n                                                                                                Voracek's sneaky goal\n                                                                                            \n\n                                                                                                Jakub Voracek fires a sharp-angle shot that gets through Joonas Korpisalo\n                                                                                            \n\n\n\n\n\n\n"}
# {'_id': ObjectId('5db4e7f937f2594786350dc5'), 'title': '\n\n\n                                                                                                Hawerchuk on minds during NHL Legacy Luncheon\n                                                                                            \n\n                                                                                                Former Jets captain, member of Hockey Hall of Fame, has stomach cancer\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc6'), 'title': '\n\n\n                                                                                                NHL DFS picks, projections, strategy\n                                                                                            \n\n                                                                                                Islanders goalies stingy during six-game winning streak; more daily fantasy targets\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc7'), 'title': '\n\n\n                                                                                                Svechnikov wires home PPG\n                                                                                            \n\n                                                                                                Andrei Svechnikov stickhandles to the circle and rifles a wrister that beats Corey Crawford short side for his first NHL power-play goal and a 1-0 lead\n                                                                                            \n\n\n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc8'), 'title': '\n\n\n                                                                                                Oct. 26: Gretzky becomes first NHL player with 2,000 points\n                                                                                            \n\n                                                                                                Plus: Lemieux scores 500th goal; Sabres win 10th straight game from start of season\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dc9'), 'title': '\n\n\n                                                                                                NHL DFS picks, projections, strategy\n                                                                                            \n\n                                                                                                Islanders goalies stingy during six-game winning streak; more daily fantasy targets\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dca'), 'title': '\n\n\n                                                                                                Svechnikov wires home PPG\n                                                                                            \n\n                                                                                                Andrei Svechnikov stickhandles to the circle and rifles a wrister that beats Corey Crawford short side for his first NHL power-play goal and a 1-0 lead\n                                                                                            \n\n\n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dcb'), 'title': "\n\n\n                                                                                                Saskamoose meets Bettman\n                                                                                            \n\n                                                                                                NHL's first indigenous player expressed honor of having Heritage Classic in Saskatchewan\n                                                                                            \n\n\n\n\n"}
# {'_id': ObjectId('5db4e7f937f2594786350dcc'), 'title': '\n\n\n\n\n\n\n\n\n\n'}
# {'_id': ObjectId('5db4e7f937f2594786350dcd'), 'title': '\n\n\n                                                                                                2019 Class Induction: Nov. 15-18\n                                                                                            \n\n                                                                                                Celebrate Carbonneau, Nedomansky, Rutherford, Wickenheiser, York & Zubov November 15-18 in Toronto\n                                                                                            \n\n\n\n\n'}
# {'_id': ObjectId('5db7177323f50f16b6bff1ed'), 'header': 'Coyle, Bruins find inspiration in 3-year-old who had brain tumor', 'subheader': 'Quinn Waters to drop puck against Sharks as part of Hockey Fights Cancer month', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1ee'), 'header': 'Marchand leads 3 Stars of the Week', 'subheader': 'Bruins forward, Predators defenseman Josi, Flyers goalie Elliott earn honors', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1ef'), 'header': 'Tarasenko to have surgery, re-evaluated in five months by Blues', 'subheader': 'Forward injured in win against Kings', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f0'), 'header': 'Facts and Figures: Ekblad, Boyle, Acciari power Panthers', 'subheader': 'Score three goals in 2:36 of second, fastest to start period in Florida history', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f1'), 'header': 'Fantasy hockey top 10 waiver wire pickups', 'subheader': 'Compher, van Riemsdyk producing in top-six roles; Koskinen, Elliott timeshare goalies to consider', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f2'), 'header': 'Projected lineups, starting goalies for today', 'subheader': 'Latest line combinations, defense pairs, injury news from NHL.com writers', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f3'), 'header': "Red Wings' patience tested during eight-game losing streak", 'subheader': 'Encouraging signs not enough in OT loss to Blues', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f4'), 'header': "McDavid against Crosby, Getzlaf's 1,000th game highlight week in NHL", 'subheader': "Stamkos eyeing 400th goal, Sabres-Coyotes matchup among can't-miss events", 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f5'), 'header': 'Color of Hockey: Abercrombie takes next step toward NHL coaching dream', 'subheader': 'Hockey Is For Everyone alumnus joins NCAA Division III Stevenson as assistant', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f6'), 'header': 'Fantasy hockey line top 25 rankings for 2019-20', 'subheader': "Two Flyers units join list; rookie Hughes settling in on Devils' first trio; Stars drop out", 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f7'), 'header': 'Rookie watch: Samsonov, Demko among top first-year goalies', 'subheader': 'Young players learning, growing while performing in backup roles for Capitals, Canucks', 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f8'), 'header': 'Blackhawks roll out purple carpet for Hockey Fights Cancer night', 'subheader': 'Olczyk emcees as team honors survivors, families of those lost', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1f9'), 'header': 'Krueger has Sabres playing connected during fast start', 'subheader': "Coach helped build players' confidence, believing early success is sustainable", 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1fa'), 'header': 'Syndergaard rides Zamboni, shoots T-shirt cannon at Islanders game', 'subheader': 'Mets pitcher makes appearance at Nassau Coliseum on Sunday', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1fb'), 'header': 'NHL DFS picks, projections, strategy', 'subheader': "Hughes has power-play point streak on Canucks' first unit; more daily fantasy targets", 'date': '2019-10-28'}
# {'_id': ObjectId('5db7177323f50f16b6bff1fc'), 'header': 'Jets hoping to build on win against Flames in Heritage Classic', 'subheader': 'Comeback can provide spark to end scoring woes', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1fd'), 'header': 'Martin, Kuhnhackl out 4-6 weeks for Islanders', 'subheader': 'Each forward has lower-body injury', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1fe'), 'header': 'Parros hustles back from Heritage Classic for charity game in New York', 'subheader': 'Joins other former NHL players, celebrities for Face Off to Fight Cancer', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff1ff'), 'header': 'Lowry to have hearing for actions in Jets game against Flames', 'subheader': 'Forward facing discipline for boarding Kylington', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff200'), 'header': '2019-20 NHL Trade Tracker', 'subheader': 'Official deals since June 14', 'date': '2019-10-26'}
# {'_id': ObjectId('5db7177323f50f16b6bff201'), 'header': "Gaudreau, Flames' top line show positive signs in Heritage Classic", 'subheader': 'Forward combines with Lindholm, Tkachuk to create chances, score only goal against Jets', 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff202'), 'header': 'Gudbranson traded to Ducks by Penguins', 'subheader': 'Pittsburgh receives forward Martinsen, seventh-round pick in 2021 NHL Draft', 'date': '2019-10-25'}
# {'_id': ObjectId('5db7177323f50f16b6bff203'), 'header': 'NHL fantasy team power rankings for 2019-20', 'subheader': "Kane's power-play impact has Sharks trending up; Bailey emerges as streaming option from Islanders", 'date': '2019-10-25'}
# {'_id': ObjectId('5db7177323f50f16b6bff204'), 'header': 'Heritage Classic Diary: Bryan Little', 'subheader': "Jets center describes 'awesome feeling' scoring in overtime outdoors against Flames", 'date': '2019-10-27'}
# {'_id': ObjectId('5db7177323f50f16b6bff205'), 'header': 'Fantasy hockey top 200 rankings for 2019-20', 'subheader': 'Eichel joins first 25; Oshie gives Capitals six among 100 best; Burakovsky added to list after Rantanen injury', 'date': '2019-10-25'}
# {'_id': ObjectId('5db7177323f50f16b6bff206'), 'header': 'Oct. 28: Orr scores final NHL goal', 'subheader': 'Plus: 100th shutout for Sawchuk; Crosby gets first hat trick', 'date': '2019-10-28'}
